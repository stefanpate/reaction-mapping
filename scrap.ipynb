# %%
from rdkit import Chem
from rdkit.Chem import AllChem

# %%
smi = 'c1cc(F)ccc1Cl'
mol = Chem.MolFromSmiles(smi)
patt = Chem.MolFromSmarts('ClccccF')
hit_ats = list(mol.GetSubstructMatch(patt))
hit_ats
# Out:
# [7, 6, 5, 4, 2, 3]

# %%
sma = '[#6:1]-[#8:2].[#6:3]1:[#6:4]:[#6:5]:[#6:6]:[#7+:7]:[#6:8]:1>>[#6:3]1=[#6:8]-[#7+0:7]-[#6:6]=[#6:5]-[#6:4]-1.[#6:1]=[#8:2]'.split('>>')[0]
sma
from_smi = Chem.MolFromSmiles(sma)
from_sma = Chem.MolFromSmarts(sma)
from_smi

# %%
from_sma
